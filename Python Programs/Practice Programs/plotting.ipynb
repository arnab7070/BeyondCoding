# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([1,2,3,4])
ypoints = np.array([2,3,4,5])
# plt.plot(xpoints,ypoints,marker='o')
plt.show()

# %%
# scores = np.array([10,6,15,14,9,7])
# over = np.array([1,2,3,4,5,6])
# plt.plot(over,scores,marker='o',color="green")
# plt.bar(over,scores,color="green")
# example_histogram = np.random.normal(150,10,280)
# plt.hist(example_histogram)
# plt.xlabel("Over")
# plt.ylabel("Score/Over")
percentage = np.array([90,70,80,50,40])
languages = np.array(["Python","Javascript","C++","JAVA","PHP"])
plt.pie(percentage, labels = languages)
plt.plot()
# Out:
# []

# %%
from numpy import random
randomBill = random.randint(1000,3000,size=12)
month = np.array(['Jan','Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.pie(randomBill,labels=month)
plt.show()

# %%
xpoints = random.randint(100,size=(15))
ypoints = random.randint(100,size=(15))
plt.scatter(xpoints, ypoints, color="red")
xpoints = random.randint(100,size=(15))
ypoints = random.randint(100,size=(15))
plt.scatter(xpoints, ypoints, color="green")
plt.show()
