# %% [markdown]
# ## Summary of plotting in python

# %%
# from cProfile import label
# from turtle import color
# import matplotlib.pyplot as plt
# import numpy as np

# Initialization
# Creating array for points in x and y axis
# x = np.array([1,2,3,4])
# y = np.array([1,2,10,4])
# For plotting the points 

# Format 1
# plt.plot(x,y)
# To show the graph
# plt.show()

# Format 2
# This is the syntax for only point out the plotting points
# plt.plot(x, y, 'o')
# plt.show()

# Format 3
# To only connecting the plotting points of X or Y axis
# plt.plot(y,marker='o')
# plt.show()

# Format 4
# To add labels in X and Y axis
# plt.plot(x,y)
# plt.xlabel('Score/Over')
# plt.ylabel('Over')
# plt.show()

# Format 5
# To point out the plotting points easily with custom color in the graph
# plt.scatter(x,y,color='hotpink')

# Format 6
# Syntax for plotting bar graphs
# x = np.array(["C","C++","Python","Java"])
# y = np.array([20,35,40,45])
# plt.bar(x,y,color='green')
# plt.show()

# Format 7
# To draw a histogram from standard normal
# x = np.random.normal(70,140,20)
# plt.hist(x)
# plt.show()

# Format 8
# To draw a pie chart for a given data
# y = np.array([20,35,40,45])
# labels = np.array(["C","C++","Python","Java"])
# plt.pie(y,labels=labels)
# plt.title("PIE CHART")
# plt.show()

# %% [markdown]
# ## Seperate Execution of codes in details

# %%
import matplotlib.pyplot as plt

import numpy as np
xpoints = np.array([0, 4, 6])
ypoints = np.array([0, 50, 250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np
xpoints = np.array([1,8])
ypoints = np.array([3,10])
plt.plot(xpoints,ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y, color = '#88c999')
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,25,25,15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,labels = mylabels)
plt.show()
